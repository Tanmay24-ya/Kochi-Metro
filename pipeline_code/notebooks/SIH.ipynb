# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_FOLDER = '/content/drive/MyDrive/Data Folder/KMRL'
OUTPUT_CSV = '/content/drive/MyDrive/all_extracted.csv'

# %%
# !pip install PyMuPDF pillow pytesseract
# !apt-get install tesseract-ocr
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (25.0)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 41.0 MB/s eta 0:00:00
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract, PyMuPDF
# Successfully installed PyMuPDF-1.26.4 pytesseract-0.3.13
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'

# %%
import os
import csv
import io
from pathlib import Path
import pymupdf
from PIL import Image, ImageOps, ImageFilter
import pytesseract
import re
import unicodedata

# %%
def clean_text_english(text):
    text = unicodedata.normalize("NFKC", text)
    text = re.sub(r"[^A-Za-z0-9\s.,;:!?()'\-\"@%$&]", " ", text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def chunk_text(text, max_length=1000, overlap=200):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + max_length, len(text))
        chunks.append(text[start:end])
        start += max_length - overlap
    return chunks

# %%
def append_chunks_to_csv(chunks, output_csv, filename, department=None, page_number=None):
    file_exists = os.path.exists(output_csv)
    with open(output_csv, 'a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['source_file','department','page','chunk_index','text'])
        if not file_exists:
            writer.writeheader()
        for idx, chunk in enumerate(chunks):
            writer.writerow({
                'source_file': filename,
                'department': department,
                'page': page_number,
                'chunk_index': idx,
                'text': chunk
            })

# %%
def process_pdf(file_path, department, output_csv):
    try:
        doc = pymupdf.open(file_path)
    except Exception as e:
        print(f"Failed to open {file_path}: {e}")
        return

    for page_number, page in enumerate(doc, start=1):
        raw_text = ""

        # Extract PDF text layer
        text_blocks = page.get_text("blocks")
        if text_blocks:
            for block in text_blocks:
                txt = block[4].strip()
                if txt:
                    raw_text += " " + txt

        # Extract images & OCR
        images = page.get_images(full=True)
        if images:
            for img_index, img in enumerate(images, start=1):
                xref = img[0]
                try:
                    img_data = doc.extract_image(xref)
                    image_bytes = img_data["image"]
                    image = Image.open(io.BytesIO(image_bytes))
                except Exception as e:
                    print(f"{file_path} Page {page_number} Image {img_index} extraction error: {e}")
                    continue

                # Preprocess image
                filtered = image.filter(ImageFilter.MedianFilter(size=3))
                gray = ImageOps.grayscale(filtered)
                scale = 300 / 72
                base_w = min(int(gray.width * scale), 2500)
                base_h = min(int(gray.height * scale), 2500)
                gray_resized = gray.resize((base_w, base_h), Image.LANCZOS)

                # OCR
                try:
                    ocr_text = pytesseract.image_to_string(gray_resized)
                    raw_text += " " + ocr_text
                except Exception as e:
                    print(f"{file_path} Page {page_number} Image {img_index} OCR error: {e}")
                    continue

        # Clean & chunk
        cleaned_text = clean_text_english(raw_text)
        if not cleaned_text:
            continue

        chunks = chunk_text(cleaned_text, max_length=1000, overlap=200)

        # Append to CSV
        append_chunks_to_csv(
            chunks,
            output_csv,
            filename=os.path.basename(file_path),
            department=department,
            page_number=page_number
        )
        print(f"{file_path} Page {page_number}: {len(chunks)} chunks written.")

# %%
# -------------------------------
# 5. Traverse KMRL folder and process PDFs
# -------------------------------
def traverse_and_process(root_folder, output_csv, dept_list=None):
    root_path = Path(root_folder)
    for dept_folder in root_path.iterdir():
        if dept_folder.is_dir():
            department = dept_folder.name
 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 59: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 60: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 61: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 62: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 63: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 64: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 65: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 66: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 67: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 68: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 69: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 70: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 71: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 72: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 73: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 74: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 75: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 76: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 77: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 78: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 79: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 80: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 81: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 82: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 83: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 84: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 85: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 86: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 87: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 88: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 89: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 90: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 91: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 92: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 93: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 94: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 95: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 96: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 97: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 98: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 99: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 100: 5 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 101: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 102: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 103: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 104: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 105: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 106: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 107: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 108: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 109: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 110: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 111: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 112: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 113: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 114: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 115: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 116: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 117: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 118: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 119: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 120: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 121: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 122: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 123: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 124: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 125: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 126: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 127: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 128: 1 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 129: 4 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 130: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 131: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 132: 3 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 133: 2 chunks written.
# /content/drive/MyDrive/Data Folder/KMRL/Engineering /Nagpur Metro- Detailed Project Report (full DPR).pdf Page 134: 2 chunks written.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2107462646.py in <cell line: 0>()
#       3 DEPARTMENTS_TO_PROCESS = None
#       4
# ----> 5 traverse_and_process(ROOT_FOLDER, OUTPUT_CSV, DEPARTMENTS_TO_PROCESS)
#       6 print(f"\nAll done! CSV saved to {OUTPUT_CSV}")
#
# /tmp/ipython-input-1698073205.py in traverse_and_process(root_folder, output_csv, dept_list)
#      12             for pdf_file in dept_folder.glob("*.pdf"):
#      13                 print(f"Processing PDF: {pdf_file}")
# ---> 14                 process_pdf(pdf_file, department, output_csv)
#
# /tmp/ipython-input-1158950560.py in process_pdf(file_path, department, output_csv)
#      40                 # OCR
#      41                 try:
# ---> 42                     ocr_text = pytesseract.image_to_string(gray_resized)
#      43                     raw_text += " " + ocr_text
#      44                 except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     484     args = [image, 'txt', lang, config, nice, timeout]
#     485
# --> 486     return {
#     487         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# /usr/local/lib/python3.12/dist-packages/pytesseract/pytesseract.py in <lambda>()
#     487         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489         Output.STRING: lambda: run_and_get_output(*args),
#     490     }[output_type]()
#     491
#
# /usr/local/lib/python3.12/dist-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     350         }
#     351
# --> 352         run_tesseract(**kwargs)
#     353         return _read_output(
#     354             f"{kwargs['output_filename_base']}{extsep}{extension}",
#
# /usr/local/lib/python3.12/dist-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     280             raise TesseractNotFoundError()
#     281
# --> 282     with timeout_manager(proc, timeout) as error_string:
#     283         if proc.returncode:
#     284             raise TesseractError(proc.returncode, get_errors(error_string))
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/pytesseract/pytesseract.py in timeout_manager(proc, seconds)
#     142     try:
#     143         if not seconds:
# --> 144             yield proc.communicate()[1]
#     145             return
#     146
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
